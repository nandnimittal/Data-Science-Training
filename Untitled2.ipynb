# %%
a=8

# %%
b=9

# %%
print(a+b)
# Out:
# 17

# %%
a=99

# %%
del a

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
x=2

# %%
y='king'

# %%
print(x+y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(x+y)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
z='2'

# %%
print(y+z)
# Out:
# king2

# %%
print(str(x)+y)
# Out:
# 2king

# %%
print(x,y,z)
# Out:
# 2 king 2

# %%
type(x)
# Out:
# int

# %%
typt(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 typt(y)
#
# NameError: name 'typt' is not defined

# %%
type(y)
# Out:
# str

# %%
type(z)
# Out:
# str

# %%
print(str(x)+y+z)
# Out:
# 2king2

# %%
print(str(x)+y)
# Out:
# 2king

# %%
print(str(x)+z)
# Out:
# 22

# %%
print(x+int(z))
# Out:
# 4

# %%
z
# Out:
# '2'

# %%
m=input()
n= input()
print(m+n)
# Out:
#  34
#  2
# 342

# %%
m=int(input())
n=int(input())
print(m+n)
# Out:
#  2
#  3
# 5

# %%
i=2 #123

# %%
cc=22.4

# %%
type(cc)
# Out:
# float

# %%
dd=int(cc)

# %%
print(dd)
# Out:
# 22

# %%
e='123king'

# %%
# ''' ''' we use triple coats just for the way we write the code and give the same way
cities='''Mohali,
Nariangarh,
Landran'''

# %%
print(cities)
# Out:
# Mohali,
# Nariangarh,
# Landran

# %%
# \n used for next line 
cities2='mohali\n gwalior'

# %%
print(cities2)
# Out:
# mohali
#  gwalior

# %%
#\t used for the like tab space 
cities1='mohali\t\tnariangarh'

# %%
print(cities1)
# Out:
# mohali		nariangarh

# %%
# r = raw string as it is write it 
cities=r'ama\andni\anina\amrita\raghav'

# %%
print(cities)
# Out:
# ama\andni\anina\amrita\raghav

# %%
# if we will not use r here so it will give the error
cities='ama\andni\anina\amrita\raghav'

# %%
# see in this it will give the undesired output 
print(cities)
# Out:
# aghavdnininamrita

# %%
# we can get these values from devanagri unicode charcters ok and these are the unicode values.
value ='\u0927\u0928'

# %%
print(value)
# Out:
# धन

# %%
value='\u0929\u0926\u0928\u0940'

# %%
print(value)
# Out:
# ऩदनी

# %%
a='\u0929'
b='\u0926'
c='\u0928'
d='\u0940'

# %%
print(a+b+c+d)
# Out:
# ऩदनी

# %%
# alpha methods 
hello ='     king      '

# %%
print(hello)
# Out:
#      king

# %%
# to remove the space 
print(hello.strip())
# Out:
# king

# %%
hello.count('l')
# Out:
# 0

# %%
hello.count('i')
# Out:
# 1

# %%
hello.endswith(' ')
# Out:
# True

# %%
hello.isalpha()
# Out:
# False

# %%
hello=hello.strip()

# %%
#no space 
hello.isalpha()
# Out:
# True
