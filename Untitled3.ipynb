# %%
# list: fixed thing not changable like college, building.
list1=[]

# %%
type(list1)
# Out:
# list

# %%
list2=['king','queen','rock',22,6.5]

# %%
print(list2)
# Out:
# ['king', 'queen', 'rock', 22, 6.5]

# %%
print(list2[1])
# Out:
# queen

# %%
print(list2[-1])
# Out:
# 6.5

# %%
print(list2[1:3])
# Out:
# ['queen', 'rock']

# %%
print(list2[-2])
# Out:
# 22

# %%
print(list2[1:])
# Out:
# ['queen', 'rock', 22, 6.5]

# %%
print(list2[:3])
# Out:
# ['king', 'queen', 'rock']

# %%
list2[2] ='leaf'

# %%
print(list2)
# Out:
# ['king', 'queen', 'leaf', 22, 6.5]

# %%
list2.index('queen')
# Out:
# 1

# %%
list3 = ['king','queen','rookie','big','rock','queen','rookie','pawn']

# %%
list3
# Out:
# ['king', 'queen', 'rookie', 'big', 'rock', 'queen', 'rookie', 'pawn']

# %%
list3.index('queen')
# Out:
# 1

# %%
list3.index('queen',2,4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 list3.index('queen',2,4)
#
# ValueError: 'queen' is not in list

# %%
list3.count('queen')
# Out:
# 2

# %%
list4=[33,44,56,65,78,98,23,45,99,101]

# %%
list4.sort()

# %%
print(list4)
# Out:
# [23, 33, 44, 45, 56, 65, 78, 98, 99, 101]

# %%
list5=[33,44,56,78,98,23,45,99,101]

# %%
list5.sort(reverse=True)

# %%
print(list5)
# Out:
# [101, 99, 98, 78, 56, 45, 44, 33, 23]

# %%
list5.append('roger')

# %%
print(list5)
# Out:
# [101, 99, 98, 78, 56, 45, 44, 33, 23, 'roger']

# %%
list3.remove('queen')

# %%
print(list3)
# Out:
# ['king', 'rookie', 'big', 'rock', 'queen', 'rookie', 'pawn']

# %%
list3.index('rookie',2)
# Out:
# 5

# %%
list3.pop(5)
# Out:
# 'rookie'

# %%
list3
# Out:
# ['king', 'rookie', 'big', 'rock', 'queen', 'pawn']

# %%
list3.extend([2,3,4])

# %%
print(list3)
# Out:
# ['king', 'rookie', 'big', 'rock', 'queen', 'pawn', 2, 3, 4]

# %%
list3.extend(list4)

# %%
print(list3)
# Out:
# ['king', 'rookie', 'big', 'rock', 'queen', 'pawn', 2, 3, 4, 23, 33, 44, 45, 56, 65, 78, 98, 99, 101]

# %%
list3.insert(3,'paul')

# %%
print(list3)
# Out:
# ['king', 'rookie', 'big', 'paul', 'rock', 'queen', 'pawn', 2, 3, 4, 23, 33, 44, 45, 56, 65, 78, 98, 99, 101]

# %%
list3.insert(3,list3)

# %%
print(list3)
# Out:
# ['king', 'rookie', 'big', [...], 'paul', 'rock', 'queen', 'pawn', 2, 3, 4, 23, 33, 44, 45, 56, 65, 78, 98, 99, 101]

# %%
print(list3[3][0:1])
# Out:
# ['king']

# %%
list6=[1,2,3,4,5]

# %%
list7=['a','b','c','d']

# %%
list1=[]

# %%
type(list1)
# Out:
# list

# %%
list2=['king','queen','rock',22,6.5]

# %%
print(list2)
# Out:
# ['king', 'queen', 'rock', 22, 6.5]

# %%
print(list2[1])
# Out:
# queen

# %%
# in this -1 = 6.5 , -2 = 22 , -3 = rock in the reverse order index 
print(list2[-1])
# Out:
# 6.5

# %%
# in this queen and rock occur because 1: means including 1 se agge wale and :3 means not including 3 se phele wale
print(list2[1:3])
# Out:
# ['queen', 'rock']

# %%
print(list2[1:])
# Out:
# ['queen', 'rock', 22, 6.5]

# %%
print(list2[:3])
# Out:
# ['king', 'queen', 'rock']

# %%
list2[2]='leaf'

# %%
print(list2)
# Out:
# ['king', 'queen', 'leaf', 22, 6.5]

# %%
# find the index of queen in this .
list2.index('queen')
# Out:
# 1

# %%
list3 =['king','queen','rookie','big','rock','queen','rookie','pawn']

# %%
list3
# Out:
# ['king', 'queen', 'rookie', 'big', 'rock', 'queen', 'rookie', 'pawn']

# %%
# in list3 there are 2 queens but in the output it show only 1 the reson is it take the first occurence system in it .
list3.index('queen')
# Out:
# 1

# %%
list3.index('queen',2,4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 list3.index('queen',2,4)
#
# ValueError: 'queen' is not in list

# %%
# count tells the total count of the queen  in it .
list3.count('queen')
# Out:
# 2

# %%
list4=[33,44,56,65,78,98,23,45,99,101]

# %%
# by default it sort in a acending order in it .
list.sort()

# %%
print(list4)
# Out:
# [33, 44, 56, 65, 78, 98, 23, 45, 99, 101]

# %%
list5=[33,44,56,65,78,98,23,45,99,101]

# %%
# in this its firstly sort the list and then reverse the list.
list5.sort(reverse=True)

# %%
print(list5)
# Out:
# [101, 99, 98, 78, 65, 56, 45, 44, 33, 23]

# %%
# in this append means add the specific element in the list and at the end .
list5.append('roger')

# %%
print(list5)
# Out:
# [101, 99, 98, 78, 65, 56, 45, 44, 33, 23, 'roger']

# %%
# remove the queen at the starting not in the middle and the last only the starting of it.
list3.remove('queen')

# %%
print(list3)
# Out:
# ['king', 'rookie', 'big', 'rock', 'queen', 'rookie', 'pawn']

# %%
# 'rookie',2 means that find the place of the rookie after 2 including 2 so .
list3.index('rookie',2)
# Out:
# 5

# %%
# remove the index 5 element in the list.
list3.pop(5)
# Out:
# 'rookie'

# %%
print(list3)
# Out:
# ['king', 'rookie', 'big', 'rock', 'queen', 'pawn']

# %%
# we us extend keyword to add the list and the elemnt at the end of the list.
list3.extend([2,3,4])

# %%
print(list3)
# Out:
# ['king', 'rookie', 'big', 'rock', 'queen', 'pawn', 2, 3, 4, 2, 3, 4]

# %%
list3.extend(list4)

# %%
print(list3)
# Out:
# ['king', 'rookie', 'big', 'rock', 'queen', 'pawn', 2, 3, 4, 2, 3, 4, 33, 44, 56, 65, 78, 98, 23, 45, 99, 101]

# %%
# it means that you insert the element at the 3rd index in the list. 
list3.insert(3,'paul')

# %%
print(list3)
# Out:
# ['king', 'rookie', 'big', 'paul', 'rock', 'queen', 'pawn', 2, 3, 4, 2, 3, 4, 33, 44, 56, 65, 78, 98, 23, 45, 99, 101]

# %%
# it means at index 3 insert the list3 .
list3.insert(3,list3)

# %%
print(list3)
# Out:
# ['king', 'rookie', 'big', [...], 'paul', 'rock', 'queen', 'pawn', 2, 3, 4, 2, 3, 4, 33, 44, 56, 65, 78, 98, 23, 45, 99, 101]

# %%
# it means that in list3 at index 3 there is also an list in which 0:1 print king 
print(list3[3][0:1])
# Out:
# ['king']

# %%
list6=[1,2,3,4,5]

# %%
list7=['a','b','c','d']

# %%
# it means that in list6 at 3rd index insert list7.
list6.insert(3,list7)

# %%
print(list6)
# Out:
# [1, 2, 3, ['a', 'b', 'c', 'd'], 4, 5]

# %%
print(list6[3][0:2])
# Out:
# ['a', 'b']

# %%
# specificly at index 3 add roger in the 3rd index list.
list6[3].append('roger')

# %%
print(list6[3])
# Out:
# ['a', 'b', 'c', 'd', 'roger']

# %%
name='raja'

# %%
# variable value store not the variable.
list6.append(name)

# %%
list6
# Out:
# [1, 2, 3, ['a', 'b', 'c', 'd', 'roger'], 4, 5, 'raja']

# %%
#tuple :- tuple is faster iterationa as compared to the list.and its changable . 
#like game, list of guest

# %%
tup=('king','queen','gagan',12,2,3,4,5)

# %%
print(tup)
# Out:
# ('king', 'queen', 'gagan', 12, 2, 3, 4, 5)

# %%
# type is tuple.
type(tup)
# Out:
# tuple

# %%
# index of 3 
tup[3]
# Out:
# 12

# %%
tup.count('queen')
# Out:
# 1

# %%
tup.index('queen')
# Out:
# 1

# %%
# dictinoray :- in this there is key: value pair in it and there is no index  and it also store multiple dictionary.
student ={'name':'hitesh','contact':8607765479}

# %%
print(student)
# Out:
# {'name': 'hitesh', 'contact': 8607765479}

# %%
print(student['name'])
# Out:
# hitesh

# %%
student['name']= 'rajan'

# %%
print(student['name'])
# Out:
# rajan

# %%
student['address']= 'mohali'

# %%
print(student['address'])
# Out:
# mohali

# %%
student.update({'name':'kamal','contact':87958587858})

# %%
print(student)
# Out:
# {'name': 'kamal', 'contact': 87958587858, 'address': 'mohali'}

# %%
student.pop('address')
# Out:
# 'mohali'

# %%
print(student)
# Out:
# {'name': 'kamal', 'contact': 87958587858}

# %%
del student['name']

# %%
print(student)
# Out:
# {'contact': 87958587858}

# %%
student.update({'subject':'data science','address':'mohali'})

# %%
student
# Out:
# {'contact': 87958587858, 'subject': 'data science', 'address': 'mohali'}

# %%
# get :- you just print your own error not the system.
print(student.get('amount','value not found'))
# Out:
# value not found

# %%
print(student['amount'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 print(student['amount'])
#
# KeyError: 'amount'

# %%
students={
    'student1':{
        'name':'nandni',
        'roll no':48784
    },
    'student2':{
        'name':'nanu',
        'roll no':4784
    }
}

# %%
print(students['student1']['name'])
# Out:
# nandni

# %%
# length of student1
print(len(students['student1']))
# Out:
# 2

# %%
# keys means the keys: value
students.keys()
# Out:
# dict_keys(['student1', 'student2'])

# %%
# keys: values
students.values()
# Out:
# dict_values([{'name': 'nandni', 'roll no': 48784}, {'name': 'nanu', 'roll no': 4784}])

# %%
students.items()
# Out:
# dict_items([('student1', {'name': 'nandni', 'roll no': 48784}), ('student2', {'name': 'nanu', 'roll no': 4784})])

# %%
'name' in students['student1'].keys()
# Out:
# True

# %%
# set:- no duplicates
set2 ={'king','queen','roger','paul','queen'}

# %%
print(set2)
# Out:
# {'paul', 'roger', 'queen', 'king'}

# %%
set2.pop()
# Out:
# 'paul'

# %%
set2.update({'king'})

# %%
set2
# Out:
# {'king', 'queen', 'roger'}

# %%
set2.update({'king'})

# %%
print(set2)
# Out:
# {'roger', 'queen', 'king'}

# %%
set12={'nandni','nanni','nandni','mukku'}

# %%
print(set12)
# Out:
# {'mukku', 'nanni', 'nandni'}

# %%
set12.update({'nandni'})

# %%
set12
# Out:
# {'mukku', 'nandni', 'nanni'}
