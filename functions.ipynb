# %%
# Functions:- A function is named block of reusable code that performs a specific task.
print('hello nandni good morning ')
# Out:
# hello nandni good morning

# %%
# we need to print a print a statement many time so we use function . 
def greet():
    print('good morning Amar')

# %%
greet()
# Out:
# good morning Amar

# %%
def greet1(name):
    print(f"hello {name} good morning how are yoyu")

# %%
greet1('amit')
# Out:
# hello amit good morning how are yoyu

# %%
greet1('kamal')
# Out:
# hello kamal good morning how are yoyu

# %%
greet1('Amar')
# Out:
# hello Amar good morning how are yoyu

# %%
#def is a keyword used to create function.
def calc(a,b):
    print(a+b)

# %%
calc(2,3)
# Out:
# 5

# %%
# this is give an error we dont set any default value. 
calc(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 calc(2)
#
# TypeError: calc() missing 1 required positional argument: 'b'

# %%
# we  set an default value if we skip any of thie argument so they provide me the answer.
def calc1(a,b,c=0):
    print(a+b+c)

# %%
calc1(2,3,4)
# Out:
# 9

# %%
calc1(2,3)
# Out:
# 5

# %%
# print the addition of a,b,c and sum of all of three (d) divided by 3 .
def calc2(a,b,c):
    d= a+b+c
    d= d/3
    print(d)

# %%
calc2(2,3,23)
# Out:
# 9.333333333333334

# %%
a = greet1('raja')
# Out:
# hello raja good morning how are yoyu

# %%
# jo bhi ouput aae varible me save ho jae .
# two types of variable global and local
#global and local two types of variable
print(a) # value is not assign .
# Out:
# None

# %% [raw]
# def greet2(name):
#     return f"hello {name} good morning"

# %%
a= greet2('pawn')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 a= greet2('pawn')
#
# NameError: name 'greet2' is not defined

# %%
def greet4(name):
    return f"hello {name} good morning"

# %%
aa = greet4('pawn')

# %%
print(aa)
# Out:
# hello pawn good morning

# %%
def sq(n):
    print(n*n)

# %%
sq(5)
# Out:
# 25

# %%
# nka square = n**n
def sq(n):
    print(n**2)

# %%
sq(5)
# Out:
# 25

# %%
def table(num):
    for i in range(2,11):
        print(f"{num} X {i} = {i*num}")

# %%
table(4)
# Out:
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# 4 X 10 = 40

# %%
def table():
    num = int(input())
    for i in range(2,11):
        print(f"{num} X {i} = {i*num}")

# %%
table()
# Out:
#  5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %%
def table():
    num = int(input())
    for i in range(2,11):
        print(f"{num} X {i} = {i*num}")

# %%
hh = table()
# Out:
#  5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %%
def table():
    num = int(input())
    result=[]
    for i in range(2,11):
        result.append(f"{num} X {i} = {i*num}")
    return result

# %%
hh = table()
# Out:
#  5

# %%
print(hh)
# Out:
# ['5 X 2 = 10', '5 X 3 = 15', '5 X 4 = 20', '5 X 5 = 25', '5 X 6 = 30', '5 X 7 = 35', '5 X 8 = 40', '5 X 9 = 45', '5 X 10 = 50']

# %%
for i in hh:
    print(i)
# Out:
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# 5 X 10 = 50

# %%
list22=[]
for i in range(1,10):
    list22.append(i)

# %%
list22
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
def multiple(a,b):
    return a+b,a*b

# %%
az= multiple(2,3)

# %%
print(az)
# Out:
# (5, 6)

# %%
# we give multiple ouputs here a, z = 
a,z = multiple(2,3)

# %%
print(a,z)
# Out:
# 5 6

# %%
type(az)
# Out:
# tuple

# %%
# *args = agruments not defined  how much u can take no need to defined just write *args . 
def calc22(*args):
    sum = 0
    for i in args:
        sum += i
    return sum

# %%
calc22(2,3,4,5,5,6,7,7,7,)
# Out:
# 46

# %%
# find average - len :- kisi bhi variable ki length.
def calc22(*args):
    sum = 0
    length = 0
    for i in args:
        sum += i
    length = len(args)
    print(length,sum)
    return sum/length

# %%
calc22(2,2,2,2,2,2)
# Out:
# 6 12
# 2.0

# %%
# its included the space also .
name = 'i am the king'

# %%
len(name)
# Out:
# 13

# %%
def add(a,b):
    print(a+b)

# %%
def sub(a,b):
    print(a-b)

# %%
def mul(a,b):
    print(a*b)

# %%
ops=['+','-','*']

# %%
print('calculator')
choice = input('enter choice')
num1 = int(input('num1'))
num2 = int(input('num2'))
if choice == 'add':
    add(num1,num2)
elif choice == 'sub':
    sub(num1,num2)
elif choice == 'mul':
    mul(num1,num2)
else:
    print('wrong choice')
# Out:
# calculator
# enter choice add
# num1 1
# num2 1
# 2

# %%
print('calculator')
choice = input('Enter the choice')
num1 = int(input('Enter the num1'))
num2 = int(input('Enter the num2'))
if choice &&:
    if choice == add:
       add(num1,num2)
    elif choice == 'sub':
       sub(num1,num2)
    elif choice == 'mul':
       /mul(num1,num2)
else:
    print('wrong choice')
# Out:
# calculator
# Enter the choice add
# Enter the num1 2
# Enter the num2 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 5
#       3 num1 = int(input('Enter the num1'))
#       4 num2 = int(input('Enter the num2'))
# ----> 5 if choice == correct:
#       6     if choice == add:
#       7        add(num1,num2)
#
# NameError: name 'correct' is not defined

# %%
def new_calc():
    print('calculator')
    print(f"+ for addition")
    print(f"- for subtraction")
    print(f"* for multiplication")
    num1 = int(input('num1'))
    num2= int(input('num2'))
    choice = input('Enter your op +,-,*')
    if choice in ops:
        if choice == '+':
           add(num1,num2)
        elif choice == '-':
           sub(num1,num2)
        elif choice == '*':
           mul(num1,num2)
    else: 
        print('Enter correct choice')

# %%
new_calc()
# Out:
# calculator
# + for addition
# - for subtraction
# * for multiplication
# num1 4
# num2 4
# Enter your op +,-,* +
# 8

# %%
user = input('Entre username')
if user == 'admin':
    password = input('Enter password')
    if password == '123456':
        new_calc()
    else:
        print('wrong password')
else:
    print('wrong user')
# Out:
# Entre username admin
# Enter password 123456
# calculator
# + for addition
# - for subtraction
# * for multiplication
# num1 1
# num2 2
# Enter your op +,-,* +
# 3

# %% [raw]
# passwords= []
# users=[]

# %%
passwords= []
users=[]

# %%
# list h user name ki append krna h list h passwords ki append  uppelowerletteralphaspecialcharacter., length of six.
username= input('Enter username')
password = input('Enter password')
if len(password)<6:
    print('password too short')
elif ' ' in password:
    print('no space allowed')
elif not any ( i in  '!@#$%^&*()_+' for i in password):
    print('password must have special character')
elif not any (char.isupper() for char in password):
    print('password must have upper char')
elif not any (char.islower() for char in password):
    print('password must have lpwer char')
elif not any (char.isdigit() for char in password):
    print('password must have numbers')
else:
    print('password is strong')
    password.append(password)
    users.append(username)
# Out:
# Enter username hitesh
# Enter password dhagyvsh@@#
# password must have upper char

# %%
passwords
# Out:
# []

# %%
user1 = input('Enter username')
if user1 in users:
    idx = users.index(user1)
    password1 = input('enter password')
    if password == password[idx]:
        new_calc()
    else:  
        print('invalid password')
else:
    print('invalid user')
# Out:
# Enter username hitesh
# invalid user

# %%
print('calculator')
choice=input('enter choice')
num1=int(input('num1'))
num2=int(input('num2'))
if choice == 'add':
    add(num1, num2)
elif choice == 'sub':
    sub(num1, num2)
elif choice == 'mul':
    mul(num1, num2)
else:
    print('wrong choice')
# Out:
# calculator
# enter choice mul
# num1 45
# num2 54
# 2430

# %%
print('calculator')
print(f"+ for addition")
print(f"- for subtraction")
print(f"* for multiplication")
num1=int(input('num1'))
num2=int(input('num2'))
choice=input('enter your op +, - or *')
if choice in ops:
    if choice == '+':
        add(num1, num2)
    elif choice == '-':
        sub(num1, num2)
    elif choice == '*':
        mul(num1, num2)
else:
    print('enter correct choice')
# Out:
# calculator
# + for addition
# - for subtraction
# * for multiplication
# num1 23
# num2 32
# enter your op +, - or * =
# enter correct choice

# %%
def new_calc():
    print('calculator')
    print(f"+ for addition")
    print(f"- for subtraction")
    print(f"* for multiplication")
    num1=int(input('num1'))
    num2=int(input('num2'))
    choice=input('enter your op +, - or *')
    if choice in ops:
        if choice == '+':
            add(num1, num2)
        elif choice == '-':
            sub(num1, num2)
        elif choice == '*':
            mul(num1, num2)
    else:
        print('enter correct choice')

# %%
new_calc()
# Out:
# calculator
# + for addition
# - for subtraction
# * for multiplication
# num1 23
# num2 32
# enter your op +, - or * *
# 736

# %%
user=input('enter username')
if user == 'admin':
    password=input('enter password')
    if password == '123456':
        new_calc()
    else:
        print('wrong password')
else:
    print('wrong username')
# Out:
# enter username admin
# enter password 123456
# calculator
# + for addition
# - for subtraction
# * for multiplication
# num1 32
# num2 33
# enter your op +, - or * -
# -1

# %%
passwords=[]
users=[]

# %%
username=input('enter user name')
password=input('enter password')
if len(password)<6:
    print('password too short')
elif ' ' in password:
    print('no space allowed')
elif not any (i in '!@#$%^&*()_+' for i in password ):
    print('password must have special characters')
elif not any (char.isupper() for char in password):
    print('password must have upper chars')
elif not any (char.islower() for char in password):
    print('password must have small letter')
elif not any (char.isdigit() for char in password):
    print('password must have numbers')
else:
    print('password is strong')
    passwords.append(password)
    users.append(username)
# Out:
# enter user name hitesh
# enter password Sharma123$
# password is strong

# %%
passwords
# Out:
# ['Sharma123$']

# %%
users
# Out:
# ['hitesh']

# %%
list1 = [ 'nanndi','namrita','manu']
userpass=[123,456,789]

# %%
userpass[2]
# Out:
# 789

# %%
user1=input('enter username')
if user1 in users:
    idx=users.index(user1)
    password1=input('enter password')
    if password1==passwords[idx]:
        new_calc()
    else:
        print('invalid password')
else:
    print('invalid user')
# Out:
# enter username hitesh
# enter password Sharma123$
# calculator
# + for addition
# - for subtraction
# * for multiplication
# num1 23
# num2 32
# enter your op +, - or * +
# 55

# %%
def secure_calc():
    user1=input('enter username')
    if user1 in users:
        idx=users.index(user1)
        password1=input('enter password')
        if password1==passwords[idx]:
            new_calc()
        else:
            print('invalid password')
    else:
        print('invalid user')

# %%
def check():
    username=input('enter user name')
    password=input('enter password')
    if len(password)<6:
        print('password too short')
    elif ' ' in password:
        print('no space allowed')
    elif not any (i in '!@#$%^&*()_+' for i in password ):
        print('password must have special characters')
    elif not any (char.isupper() for char in password):
        print('password must have upper chars')
    elif not any (char.islower() for char in password):
        print('password must have small letter')
    elif not any (char.isdigit() for char in password):
        print('password must have numbers')
    else:
        print('password is strong')
        passwords.append(password)
        users.append(username)

# %%
operation=input('enter choice')
if operation=='password':
    check()
elif operation == 'calc':
    secure_calc()
else:
    print('wrong choice')
# Out:
# enter choice calc
# enter username amar
# invalid user
