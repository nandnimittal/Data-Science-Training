# %%
#regrex(regular expression library):- regex(short for regular expression) is a specialized, compact syntax used to define search patternd within text
import re

# %%
text ="My number is 8328480348"

# %%
# \d:- digits use hote h regex mein
result = re.search(r"\d{10}",text)
print(result.group())
# Out:
# 8328480348

# %%
number = result.group()

# %%
print(number)
# Out:
# 8328480348

# %%
number = int(number)

# %%
type(number)
# Out:
# int

# %%
number
# Out:
# 8328480348

# %%
message = 'i have got 89 marks in english and  89 in hindi and 100 in maths'

# %%
# + means search aage agge in the list. findall means :- find all th elements .
marks=re.findall(r"\d+", message)

# %%
print(marks)
# Out:
# ['89', '89', '100']

# %%
type(marks)
# Out:
# list

# %%
#
total = 0

for i in marks:
    a = int(i)
    total += a
print(total)
# Out:
# 278

# %%
# repace 
re.sub(r"\d","*",message)
# Out:
# 'i have got ** marks in english and  ** in hindi and *** in maths'

# %%
message
# Out:
# 'i have got 89 marks in english and  89 in hindi and 100 in maths'

# %%
re.match(r"\d+","123abc456")
# Out:
# <re.Match object; span=(0, 3), match='123'>

# %%
re.split(r"\s+",message)
# Out:
# ['i',
#  'have',
#  'got',
#  '89',
#  'marks',
#  'in',
#  'english',
#  'and',
#  '89',
#  'in',
#  'hindi',
#  'and',
#  '100',
#  'in',
#  'maths']

# %%
password = input('enter password')
pattern = r"^(?=.*[A-Z])(?=.*[a-z])(?=.*\d)(?=.*[!@#$%^&*()])[A-Za-z\d@$!%*&?&]{8,}$"
if re.match(pattern,password):
    print('strong password')
else:
    print('weak password')
# Out:
# enter password gfgfgf
# weak password

# %%
password = input('enter pass')
if len(password)<6:
    print('minimum 6 char required ')
elif not re.search(r"[A-Z]",password):
    print('at least 1 capital letter required')
elif not re.search(r" [a-z]", password):
    print('at least 1 small char req')
elif not re.search(r"\d", password):
    print('at least 1 digit required')
elif not re.search(r"[@#$%^&*]" , password):
    print('special char req')
else:
    print('strong password')
# Out:
# enter pass rdyfy*&^
# at least 1 capital letter required

# %%
#  lamda :-one liner ,

# %%
def add(a,b):
    print(a+b)

# %%
add(4,5)
# Out:
# 9

# %%
add1 = lambda a,b: a+b

# %%
a = add1(2,3)

# %%
a
# Out:
# 5

# %%
is_even = lambda a : a % 2 == 0

# %%
is_even(8)
# Out:
# True

# %%
greater = lambda a, b: a if a > b else b

# %% [raw]
# greater(5,7)

# %%
greater(5,7)
# Out:
# 7

# %%
even = lambda a : "even" if  a % 2 == 0 else "odd"

# %%
even(8)
# Out:
# 'even'

# %%
# mapping :- list me se ,multiple items me map krna and filter krke nikalna .

# %%
def sqr(x):
    return x*x

# %%
sqr(5)
# Out:
# 25

# %%
nums=[2,3,5,6,7]

# %%
list(map(sqr,nums))
# Out:
# [4, 9, 25, 36, 49]

# %%
list(map(lambda x: "even" if x % 2 == 0 else "odd", nums))
# Out:
# ['even', 'odd', 'odd', 'even', 'odd']

# %%
# filter

# %%
list(filter(lambda x: x % 2 == 1 , nums))
# Out:
# [3, 5, 7]

# %%
marks = [23,30,35,40]

# %%
list(filter(lambda x : x > 30 , marks))
# Out:
# [35, 40]

# %%
list(filter(lambda x : x+5 if x> 30 else " not pass" , marks))
# Out:
# [23, 30, 35, 40]

# %%
a=10

# %%
a += 1

# %%
print(a)
# Out:
# 11

# %%
account = 1000
debit = 0
credit = 0

# %%
def credit(amount):
    global account
    account += amount

# %%
credit(1000)

# %%
print(account)
# Out:
# 2000

# %%
def credit(amount):
    global account
    account += amount

# %%
credit(500)

# %%
print(account)
# Out:
# 2500
